# %%
import os
import sqlite3
con = sqlite3.connect('database.sqlite')
cursorObj = con.cursor()
cursorObj.execute("select team_long_name as Team_Long_Name,avg((buildUpPlaySpeed+buildUpPlayDribbling+buildUpPlayPassing+chanceCreationPassing+chanceCreationCrossing+chanceCreationShooting+defencePressure+defenceAggression+defenceTeamWidth)/9) as Average_of_Attributes from Team_Attributes,Team where Team.team_api_id = Team_Attributes.team_api_id group by Team_Attributes.team_api_id order by Average_of_Attributes desc;")
rows = cursorObj.fetchall()

for row in rows:
  print(row)
# Out:
# ('Lazio', 62.5)
# ('Udinese', 59.0)
# ('SL Benfica', 59.0)
# ('FC Porto', 59.0)
# ('Napoli', 58.5)
# ('Widzew Łódź', 57.0)
# ('Widzew Łódź', 57.0)
# ('Chievo Verona', 57.0)
# ('Birmingham City', 57.0)
# ('VfL Wolfsburg', 57.0)
# ('FC Basel', 57.0)
# ('TSG 1899 Hoffenheim', 56.5)
# ('Aberdeen', 56.5)
# ('Lech Poznań', 56.0)
# ('Burnley', 56.0)
# ('Milan', 56.0)
# ('Celtic', 56.0)
# ('Inter', 55.5)
# ('Granada CF', 55.0)
# ('Sassuolo', 55.0)
# ('Leicester City', 55.0)
# ('Hamilton Academical FC', 55.0)
# ('Sporting CP', 55.0)
# ('Borussia Dortmund', 55.0)
# ('Torino', 55.0)
# ('Heart of Midlothian', 55.0)
# ('Bayer 04 Leverkusen', 54.5)
# ('Paris Saint-Germain', 54.5)
# ('CD Tenerife', 54.5)
# ('CS Marítimo', 54.5)
# ('Rio Ave FC', 54.0)
# ('Fortuna Düsseldorf', 54.0)
# ('Cagliari', 54.0)
# ('Empoli', 54.0)
# ('Olympique de Marseille', 54.0)
# ('Real Madrid CF', 54.0)
# ('RCD Mallorca', 54.0)
# ('FC Sochaux-Montbéliard', 54.0)
# ('Lierse SK', 54.0)
# ('Hércules Club de Fútbol', 54.0)
# ...
